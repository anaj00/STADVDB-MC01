# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('mysql://root:12345@localhost/seriousmd')

# %%
# Use double backslashes or a raw string for the file path on Windows
df = pd.read_csv('./clinics.csv', encoding='latin1')

df.to_sql('clinics', engine, if_exists='replace', index=False)
# Out:
# 53962

# %%
# Use double backslashes or a raw string for the file path on Windows
df = pd.read_csv('./doctors.csv', encoding='latin1')

df.to_sql('doctors', engine, if_exists='replace', index=False)
# Out:
# 60024

# %%
# Use double backslashes or a raw string for the file path on Windows
df = pd.read_csv('./px.csv', encoding='latin1')

df.to_sql('px', engine, if_exists='replace', index=False)
# Out:
# C:\Users\janam\AppData\Local\Temp\ipykernel_2788\69411819.py:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./px.csv', encoding='latin1')
# 6507813

# %%
# Use double backslashes or a raw string for the file path on Windows
df = pd.read_csv('./appointments.csv', encoding='latin1')

#  Change 'root' to the name of your user; '12345' to the password of your connection, 'seriousmd' to the name of your schema

df.to_sql('appointments', engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# File c:\Users\janam\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:1938, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1937     if not evt_handled:
# -> 1938         self.dialect.do_executemany(
#    1939             cursor,
#    1940             str_statement,
#    1941             effective_parameters,
#    1942             context,
#    1943         )
#    1944 elif not effective_parameters and context.no_parameters:
#
# File c:\Users\janam\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:175, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     174 def do_executemany(self, cursor, statement, parameters, context=None):
# ...
